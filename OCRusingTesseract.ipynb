# %% [markdown]
# <a href="https://colab.research.google.com/github/moaaz12-web/LayoutLM/blob/main/OCRusingTesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai googletrans==3.1.0a0

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2build2).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # IMPORTS

# %%
import pytesseract
import shutil
import os
import random
import cv2
from google.colab.patches import cv2_imshow
try:
    from PIL import Image
except ImportError:
    import Image

# %% [markdown]
# # UPLOAD ALL AND ANY IMAGES YOU  WANT TO TEST

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-325e98b0-548e-4abd-a9f8-4b68c6cce0d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-325e98b0-548e-4abd-a9f8-4b68c6cce0d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # EXAMPLE 1

# %% [markdown]
# **Let's display the image first.**

# %%
# Load the image
img = cv2.imread('/content/11.03.2023_01.35.28_REC.png')

# Display the image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=781x502 at 0x7FC56EACC4F0>

# %% [markdown]
# **Results**

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/11.03.2023_01.35.28_REC.png'))

# %%
print(extractedInformation)
# Out:
# MODELS TOTRY
#
# ARIMA:
#
# ARIMA (AutoRegressive Integrated Moving Average): ARIMA is a popular time series model that can
# capture both the trend and seasonality of the data. Its a flexible model that can handle a variety of
# time series data and has been used in many forecasting applications. However, these models do not
# included detecting seasonality in the dataset. If the dataset does contain seasonality, you should
# probably ignore this model. Otherwise, give it a try!
#
# SARIMA:
#
# SARIMA (Seasonal ARIMA): SARIMA isa variation of ARIMA that is designed to capture seasonality in
# the data, It includes additional seasonal parameters to capture the seasonal pattern in the data,
# which can be especially useful for modeling the demand for LNG, which may have seasonal patterns.
#
# SARIMAX:
#
# SARIMAX is an extension of the SARIMA model that includes additional exogenous variables, which
# ...

# %% [markdown]
# # EXAMPLE 2

# %% [markdown]
# **Let's display the image first.**

# %%
# Load the image
img = cv2.imread('IMG.png')

# Display the image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=776x630 at 0x7FC57D471E50>

# %% [markdown]
# **Results.**

# %%
extractedInformation3 = pytesseract.image_to_string(Image.open('IMG.png'))

# %%
print(extractedInformation3)
# Out:
# « Performance decrease for lower font size 1n low-resolution images
#
# * Doesn't work well on complex Forms
#
# If you want to have text detection and recognition using a single function,
# check out this Al-based Opensource Easy OCR. It supports 70+ languages
# and faster GPU Inference.
#
# Note: For Blur, Noisy and colorful image we need to follow some image-
# processing steps like making image black and white, remove salt and pepper
# noise using lowpass filters such as averaging filters or Gaussian Filter, We can
# also make blur image sharpen by using Highpass filter such as Sobel filters.
# This Image Processing operation can also be implemented by the OpenCV
# library in python.
#
# Don't Forget to Clap if you found this article helpful,
#
# Follow my telegram channel to get awesome blogs, projects, and learning
# opportunities for Python, Machine Learning, and Data Science Stuff.
#
#
#
# Stay Pythonic!!@

# %% [markdown]
# # EXAMPLE 3

# %% [markdown]
# **Let's display the image first.**

# %%
# Load the image
img = cv2.imread('/content/Screenshot 2023-03-11 015421.png')

# Display the image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=389x460 at 0x7FC56EA5CAF0>

# %% [markdown]
# **Results**

# %%
extractedInformation3 = pytesseract.image_to_string(Image.open('/content/Screenshot 2023-03-11 015421.png'))

# %%
print(extractedInformation3)

# %% [markdown]
# **No results are shown, so it is necessary to use a digital image that is clear.**

# %% [markdown]
# **Now, we only need to create an API for the above small function. After that, we can send the extracted text to the question answering API simply.**

# %% [markdown]
# # API FUNCTION

# %%
# Function to extract text from an image using pytesseract
def extract_text_from_image(image_path):
    # Open the image
    image = Image.open(image_path)

    # Extract text from the image using pytesseract
    text = pytesseract.image_to_string(image)

    # Return the extracted text
    return text

# %%
print(extract_text_from_image('/content/IMG.png'))
# Out:
# « Performance decrease for lower font size 1n low-resolution images
#
# * Doesn't work well on complex Forms
#
# If you want to have text detection and recognition using a single function,
# check out this Al-based Opensource Easy OCR. It supports 70+ languages
# and faster GPU Inference.
#
# Note: For Blur, Noisy and colorful image we need to follow some image-
# processing steps like making image black and white, remove salt and pepper
# noise using lowpass filters such as averaging filters or Gaussian Filter, We can
# also make blur image sharpen by using Highpass filter such as Sobel filters.
# This Image Processing operation can also be implemented by the OpenCV
# library in python.
#
# Don't Forget to Clap if you found this article helpful,
#
# Follow my telegram channel to get awesome blogs, projects, and learning
# opportunities for Python, Machine Learning, and Data Science Stuff.
#
#
#
# Stay Pythonic!!@
